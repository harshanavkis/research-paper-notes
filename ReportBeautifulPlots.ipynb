# %%
from matplotlib import pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Linear Interpolation

# %% [markdown]
# # block1_pool

# %% [markdown]
# ## 10 percent loss

# %%
p = plt.imread('block1_pool_0.1.jpg')
plt.axis('off')
plt.rcParams["figure.figsize"] = [10, 6]
plt.imshow(p)

# %%
p = plt.imread('block1_pool_0.3.jpg')
plt.axis('off')
plt.rcParams["figure.figsize"] = [10, 6]
plt.imshow(p)

# %%
p = plt.imread('block1_pool_0.5.jpg')
plt.axis('off')
plt.rcParams["figure.figsize"] = [10, 6]
plt.imshow(p)

# %% [markdown]
# ## block2_pool

# %%
p = plt.imread('block2_pool_0.1.jpg')
plt.axis('off')
plt.rcParams["figure.figsize"] = [10, 6]
plt.imshow(p)

# %%
p = plt.imread('block2_pool_0.3.jpg')
plt.axis('off')
plt.rcParams["figure.figsize"] = [10, 6]
plt.imshow(p)

# %%
p = plt.imread('block2_pool_0.5.jpg')
plt.axis('off')
plt.rcParams["figure.figsize"] = [10, 6]
plt.imshow(p)

# %% [markdown]
# ## block3_pool

# %%
p = plt.imread('block3_pool_0.1.jpg')
plt.axis('off')
plt.rcParams["figure.figsize"] = [10, 6]
plt.imshow(p)

# %%
p = plt.imread('block3_pool_0.3.jpg')
plt.axis('off')
plt.rcParams["figure.figsize"] = [10, 6]
plt.imshow(p)

# %%
p = plt.imread('block3_pool_0.5.jpg')
plt.axis('off')
plt.rcParams["figure.figsize"] = [10, 6]
plt.imshow(p)

# %% [markdown]
# # Nearest neighbour interpolation

# %% [markdown]
# ## block1_pool

# %%
p = plt.imread('NN_block1_pool_0.1.jpg')
plt.axis('off')
plt.rcParams["figure.figsize"] = [10, 6]
plt.imshow(p)

# %%
p = plt.imread('NN_block1_pool_0.3.jpg')
plt.axis('off')
plt.rcParams["figure.figsize"] = [10, 6]
plt.imshow(p)

# %%
p = plt.imread('NN_block1_pool_0.5.jpg')
plt.axis('off')
plt.rcParams["figure.figsize"] = [10, 6]
plt.imshow(p)

# %% [markdown]
# ## block2_pool

# %%
p = plt.imread('NN_block2_pool_0.1.jpg')
plt.axis('off')
plt.rcParams["figure.figsize"] = [10, 6]
plt.imshow(p)

# %%
p = plt.imread('NN_block2_pool_0.3.jpg')
plt.axis('off')
plt.rcParams["figure.figsize"] = [10, 6]
plt.imshow(p)

# %%
p = plt.imread('NN_block2_pool_0.5.jpg')
plt.axis('off')
plt.rcParams["figure.figsize"] = [10, 6]
plt.imshow(p)

# %% [markdown]
# ## block3_pool

# %%
p = plt.imread('NN_block3_pool_0.1.jpg')
plt.axis('off')
plt.rcParams["figure.figsize"] = [10, 6]
plt.imshow(p)

# %%
p = plt.imread('NN_block3_pool_0.3.jpg')
plt.axis('off')
plt.rcParams["figure.figsize"] = [10, 6]
plt.imshow(p)

# %%
p = plt.imread('NN_block3_pool_0.5.jpg')
plt.axis('off')
plt.rcParams["figure.figsize"] = [10, 6]
plt.imshow(p)
